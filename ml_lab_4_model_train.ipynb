# %%
#classification

# %%
"""
1.binary classification:is used true or false ,1 or 0
ex:titanic survival,spam detection,

2.multi classification:is used more than 1 feature to get the target variable


ex:
x trian ,text
y train ,test
overall data 80 and 20
preprossing steps :- we get train data and test data,
we have fully proccessed data to apply for a model



-->today we are going to apply models
linear regression:-😃
non liear:- kmean,decision tree
propabilistic:navi base



confussion matrix :- true positive ,true negative ,false positive ,false negative
we can calculate accuracy ,precision ,recall,f1 score



accuracy value changes when the parameter to the particular model ups and downs and hyper permeters changes








"""
# Out:
# '\nbinary classification:is used true or false ,1 or 0\nex:titanic survival,spam detection,\n\nmulti classification:is used more than 1 feature to get the target variable\n\nex:\nx trian ,text \ny train ,test\noverall data 80 and 20\npreprossing steps :- we get train data and test data,\nwe have fully proccessed data to apply for a model\n\n\n-->today we are going to apply models \nlinear regression:-😃\nnon liear:- kmean,decision tree\npropabilistic:navi base\n\nconfussion matrix :- true positive ,true negative ,false positive ,false negative\nwe can calculate accuracy ,precision ,recall,f1 score\n\naccuracy value changes when the parameter to the particular model ups and downs\n\n\n\n\n\n\n\n\n'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sklearn
from sklearn.datasets import load_iris
#model selection
from sklearn.model_selection import train_test_split
#preprocessing
from sklearn.preprocessing import StandardScaler
#machine learning modesl
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
#check version
sklearn.__version__
# Out:
# '1.6.1'

# %%
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
"""
#the covariance formula :-
feature slection
"""
