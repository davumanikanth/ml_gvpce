# %% [markdown]
# different types of graphs with the given dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()# display the graph

# %% [markdown]
# univariate -numerical refers to data analysis invloving a single vairable that contains numerical values

# %%
data={ "salary":[25000,30000,37000,21000,27000,33000,36000,37000,39000,40000,43000,48000,37000,21000,22000,31000,36000,38000,22000,21000]}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    salary
# 0   25000
# 1   30000
# 2   37000
# 3   21000
# 4   27000

# %%
df.shape
# Out:
# (20, 1)

# %%
plt.plot(df["salary"],color="green",marker="*",linestyle=":" ,linewidth="2")

# %%
#histogram group numerical dati into categories,especially when creating a

# %%
plt.hist(["salary"],bins=5,color="green")
plt.show()

# %%
#box plot distribution ,spread ,and outliners using quartiles.display the min

# %%
plt.boxplot(df["salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d46fbba0c80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d46fbba2480>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d46fbba2ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d46fbba2420>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d46fbba1e20>],
#  'means': []}

# %%
df.loc[20]=[0]

# %%
df
# Out:
#     salary
# 0    25000
# 1    30000
# 2    37000
# 3    21000
# 4    27000
# 5    33000
# 6    36000
# 7    37000
# 8    39000
# 9    40000
# 10   43000
# 11   48000
# 12   37000
# 13   21000
# 14   22000
# 15   31000
# 16   36000
# 17   38000
# 18   22000
# 19   21000
# 20       0

# %%
df.head(25)
# Out:
#     salary
# 0    25000
# 1    30000
# 2    37000
# 3    21000
# 4    27000
# 5    33000
# 6    36000
# 7    37000
# 8    39000
# 9    40000
# 10   43000
# 11   48000
# 12   37000
# 13   21000
# 14   22000
# 15   31000
# 16   36000
# 17   38000
# 18   22000
# 19   21000
# 20       0

# %%
df.drop(index=20,inplace=True)

# %%
df
# Out:
#     salary
# 0    25000
# 1    30000
# 2    37000
# 3    21000
# 4    27000
# 5    33000
# 6    36000
# 7    37000
# 8    39000
# 9    40000
# 10   43000
# 11   48000
# 12   37000
# 13   21000
# 14   22000
# 15   31000
# 16   36000
# 17   38000
# 18   22000
# 19   21000

# %% [markdown]
# univariant

# %%
df["dept"]=["HR","IT","FINANCE","HR","IT","FINANCE","HR","IT","FINANCE","HR"]*2

# %%
df.tail()
# Out:
#     salary     dept
# 15   31000  FINANCE
# 16   36000       HR
# 17   38000       IT
# 18   22000  FINANCE
# 19   21000       HR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   salary  20 non-null     int64
#  1   dept    20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 480.0+ bytes

# %%
#pie char

# %%
count=df["dept"].value_counts()
count
# Out:
# dept
# HR         8
# IT         6
# FINANCE    6
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct="%1.2f%%",explode=[0,0.1,0.2])
plt.axis("equal")
plt.show( )

# %%
#barplot
plt.bar(count.index,count,color=["green","black","red"])
# Out:
# <BarContainer object of 3 artists>

# %%
#bivarinet

# %%
df
# Out:
#     salary     dept
# 0    25000       HR
# 1    30000       IT
# 2    37000  FINANCE
# 3    21000       HR
# 4    27000       IT
# 5    33000  FINANCE
# 6    36000       HR
# 7    37000       IT
# 8    39000  FINANCE
# 9    40000       HR
# 10   43000       HR
# 11   48000       IT
# 12   37000  FINANCE
# 13   21000       HR
# 14   22000       IT
# 15   31000  FINANCE
# 16   36000       HR
# 17   38000       IT
# 18   22000  FINANCE
# 19   21000       HR

# %%
age=np.linspace(21,65,20)

# %%
df["age"]=age

# %%
#scatter plot
plt.scatter(df["age"],df["salary"],color="orange")

# %%
sort_s=df.sort_values('salary')
sort_s
# Out:
#     salary     dept        age
# 3    21000       HR  27.947368
# 13   21000       HR  51.105263
# 19   21000       HR  65.000000
# 14   22000       IT  53.421053
# 18   22000  FINANCE  62.684211
# 0    25000       HR  21.000000
# 4    27000       IT  30.263158
# 1    30000       IT  23.315789
# 15   31000  FINANCE  55.736842
# 5    33000  FINANCE  32.578947
# 6    36000       HR  34.894737
# 16   36000       HR  58.052632
# 7    37000       IT  37.210526
# 2    37000  FINANCE  25.631579
# 12   37000  FINANCE  48.789474
# 17   38000       IT  60.368421
# 8    39000  FINANCE  39.526316
# 9    40000       HR  41.842105
# 10   43000       HR  44.157895
# 11   48000       IT  46.473684

# %%
plt.plot(sort_s['salary'],df['age'],color='green',marker='*',linestyle=':')

# %%
hr_sal=df[df["dept"]=="HR"]["salary"]
hr_sal
# Out:
# 0     25000
# 3     21000
# 6     36000
# 9     40000
# 10    43000
# 13    21000
# 16    36000
# 19    21000
# Name: salary, dtype: int64

# %%
it_sal=df[df["dept"]=="IT"]["salary"]
it_sal
# Out:
# 1     30000
# 4     27000
# 7     37000
# 11    48000
# 14    22000
# 17    38000
# Name: salary, dtype: int64
