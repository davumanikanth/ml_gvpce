# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-32fd4d8d-b45c-42db-a632-64a6199d3dd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32fd4d8d-b45c-42db-a632-64a6199d3dd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_csv=pd.read_csv("titanic.csv")

# %%
print("csv summary: ")
print(df_csv.info())
print(df_csv.describe(include="all"))
print("\n")
# Out:
# csv summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   PassengerId,Survived,Pclass,Name,Sex,Age,Fare  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes
# None
#        PassengerId,Survived,Pclass,Name,Sex,Age,Fare
# count                                              5
# unique                                             5
# top         1,0,3,Braund Mr Owen Harris,male,22,7.25
# freq                                               1

# %%
uploaded= files.upload()
# Out:
#      <input type="file" id="files-15f1b8d1-6779-4b74-a492-e15f3ff89517" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15f1b8d1-6779-4b74-a492-e15f3ff89517">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_html=pd.read_html("titanic.html")

# %%
print("html summary: ")
print(df_html[0].info())
print(df_html[0].describe(include="all"))
print("\n")
# Out:
# html summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5 non-null      int64
#  1   Survived     5 non-null      int64
#  2   Pclass       5 non-null      int64
#  3   Name         5 non-null      object
#  4   Sex          5 non-null      object
#  5   Age          5 non-null      int64
#  6   Fare         5 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 412.0+ bytes
# None
#         PassengerId  Survived    Pclass                     Name     Sex  \
# count      5.000000  5.000000  5.000000                        5       5
# unique          NaN       NaN       NaN                        5       2
# top             NaN       NaN       NaN  Braund, Mr. Owen Harris  female
# freq            NaN       NaN       NaN                        1       3
# ...

# %%
uploaded= files.upload()
# Out:
#      <input type="file" id="files-366f1106-2f20-4c27-b69f-901522024dde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-366f1106-2f20-4c27-b69f-901522024dde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_json=pd.read_json("titanic.json")

# %%
print("json summary: ")
print(df_json.info())
print(df_json.describe(include="all"))
print("\n")
# Out:
# json summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5 non-null      int64
#  1   Survived     5 non-null      int64
#  2   Pclass       5 non-null      int64
#  3   Name         5 non-null      object
#  4   Sex          5 non-null      object
#  5   Age          5 non-null      int64
#  6   Fare         5 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 412.0+ bytes
# None
#         PassengerId  Survived    Pclass                     Name     Sex  \
# count      5.000000  5.000000  5.000000                        5       5
# unique          NaN       NaN       NaN                        5       2
# top             NaN       NaN       NaN  Braund, Mr. Owen Harris  female
# freq            NaN       NaN       NaN                        1       3
# ...

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f793cbd8-3ab8-4920-8427-03315b64437e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f793cbd8-3ab8-4920-8427-03315b64437e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_xml=pd.read_xml("titanic.xml")

# %%
print("xml summary")
print(df_xml.info())
print(df_xml.describe(include="all"))
print("\n")
# Out:
# xml summary
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  5 non-null      int64
#  1   Survived     5 non-null      int64
#  2   Pclass       5 non-null      int64
#  3   Name         5 non-null      object
#  4   Sex          5 non-null      object
#  5   Age          5 non-null      int64
#  6   Fare         5 non-null      float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 412.0+ bytes
# None
#         PassengerId  Survived    Pclass                     Name     Sex  \
# count      5.000000  5.000000  5.000000                        5       5
# unique          NaN       NaN       NaN                        5       2
# top             NaN       NaN       NaN  Braund, Mr. Owen Harris  female
# freq            NaN       NaN       NaN                        1       3
# ...

# %%
url="https://example.com"
response=requests.get(url)
soup=BeautifulSoup(response.text,"html.parser")
title=soup.title.text
print("page title:" ,title)
# Out:
# page title: Example Domain
